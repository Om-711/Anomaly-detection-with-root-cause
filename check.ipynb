# %%
import pandas as pd
import numpy as np
n = 10000
timestamps = pd.date_range(start="2025-09-26", periods=n, freq='min')

services = ['frontend', 'auth-service', 'database-service', 'cache-service']
event_types = ['SERVICE_RESTART', 'CONFIG_CHANGE', 'USER_LOGIN', 'DEPLOYMENT']
log_levels = ['INFO', 'WARN', 'ERROR']

# %%
import numpy as np
import pandas as pd

cpu_base = 18
mem_base = 1507

cpu_usage = cpu_base + np.random.randint(-5, 5, size=n)
mem_usage = mem_base + np.random.randint(-250, 250, size=n)
response_time = np.random.randint(100, 110, size=n)
services_arr = np.random.choice(services, size=n)

# Random spiles
is_anomaly = np.random.rand(n) < 0.05
cpu_usage[is_anomaly] += np.random.randint(50, 70, size=is_anomaly.sum())
response_time[is_anomaly] += np.random.randint(300, 500, size=is_anomaly.sum())
is_anomaly = is_anomaly.astype(np.int8)

metrics_df = pd.DataFrame({
    'timestamp': timestamps,
    'cpu_usage': cpu_usage.astype(np.int16),
    'mem_base': mem_usage.astype(np.int32),
    'response_time': response_time.astype(np.int16),
    'service': services_arr,
    'is_anomaly': is_anomaly
})
metrics_df
# Out:
#                timestamp  cpu_usage  mem_base  response_time  \
# 0    2025-09-26 00:00:00         20      1375            106
# 1    2025-09-26 00:01:00         18      1293            103
# 2    2025-09-26 00:02:00         14      1690            104
# 3    2025-09-26 00:03:00         19      1685            109
# 4    2025-09-26 00:04:00         21      1535            108
# ...                  ...        ...       ...            ...
# 9995 2025-10-02 22:35:00         17      1422            106
# 9996 2025-10-02 22:36:00         77      1734            422
# 9997 2025-10-02 22:37:00         20      1502            105
# 9998 2025-10-02 22:38:00         15      1623            105
# 9999 2025-10-02 22:39:00         13      1754            107
#
#                service  is_anomaly
# 0        cache-service           0
# 1             frontend           0
# 2     database-service           0
# 3         auth-service           0
# 4        cache-service           0
# ...                ...         ...
# 9995          frontend           0
# 9996  database-service           1
# 9997     cache-service           0
# 9998  database-service           0
# 9999  database-service           0
#
# [10000 rows x 6 columns]

# %%
levels = np.random.choice(log_levels, size=n, p=[0.7, 0.2, 0.1])
services_arr = np.random.choice(services, size=n)

# services = ['frontend', 'auth-service', 'database-service', 'cache-service']
# log_levels = ['INFO', 'WARN', 'ERROR']

messages = np.array([
    f"{s} operation successful" if l=="INFO" else 
    f"{s} high memory usage" if l=="WARN" else 
    f"{s} error occurred"
    for s, l in zip(services_arr, levels)
])

is_anomaly = (levels == 'ERROR').astype(np.int8)

log_df = pd.DataFrame({
    'timestamp': timestamps,
    'level': levels,
    'message': messages,
    'service': services_arr,
    'is_anomaly': is_anomaly
})
log_df
# Out:
#                timestamp  level                                message  \
# 0    2025-09-26 00:00:00   INFO     cache-service operation successful
# 1    2025-09-26 00:01:00   INFO      auth-service operation successful
# 2    2025-09-26 00:02:00   INFO  database-service operation successful
# 3    2025-09-26 00:03:00  ERROR           cache-service error occurred
# 4    2025-09-26 00:04:00   INFO          frontend operation successful
# ...                  ...    ...                                    ...
# 9995 2025-10-02 22:35:00   INFO  database-service operation successful
# 9996 2025-10-02 22:36:00  ERROR            auth-service error occurred
# 9997 2025-10-02 22:37:00  ERROR           cache-service error occurred
# 9998 2025-10-02 22:38:00   INFO     cache-service operation successful
# 9999 2025-10-02 22:39:00   INFO      auth-service operation successful
#
#                service  is_anomaly
# 0        cache-service           0
# 1         auth-service           0
# 2     database-service           0
# 3        cache-service           1
# 4             frontend           0
# ...                ...         ...
# 9995  database-service           0
# 9996      auth-service           1
# 9997     cache-service           1
# 9998     cache-service           0
# 9999      auth-service           0
#
# [10000 rows x 5 columns]

# %%
event_arr = np.random.choice(event_types, size=n)
services_arr = np.random.choice(services, size=n)

# services = ['frontend', 'auth-service', 'database-service', 'cache-service']
# event_types = ['SERVICE_RESTART', 'CONFIG_CHANGE', 'USER_LOGIN', 'DEPLOYMENT']

is_anomaly = (event_arr == 'SERVICE_RESTART').astype(np.int8)

event_df = pd.DataFrame({
    'timestamp': timestamps,
    'event_type': event_arr,
    'service': services_arr,
    'is_anomaly': is_anomaly
})

event_df
# Out:
#                timestamp       event_type           service  is_anomaly
# 0    2025-09-26 00:00:00       USER_LOGIN  database-service           0
# 1    2025-09-26 00:01:00    CONFIG_CHANGE  database-service           0
# 2    2025-09-26 00:02:00       DEPLOYMENT     cache-service           0
# 3    2025-09-26 00:03:00       USER_LOGIN      auth-service           0
# 4    2025-09-26 00:04:00  SERVICE_RESTART     cache-service           1
# ...                  ...              ...               ...         ...
# 9995 2025-10-02 22:35:00       USER_LOGIN     cache-service           0
# 9996 2025-10-02 22:36:00  SERVICE_RESTART          frontend           1
# 9997 2025-10-02 22:37:00  SERVICE_RESTART          frontend           1
# 9998 2025-10-02 22:38:00       DEPLOYMENT          frontend           0
# 9999 2025-10-02 22:39:00       USER_LOGIN          frontend           0
#
# [10000 rows x 4 columns]

# %%
trace_id = np.arange(1, n+1)
duration = np.random.randint(20, 50, size=(n, len(services)))

data = []
for idx, t in enumerate(timestamps):
    parent_id = None
    for s_idx, service in enumerate(services):
        # 20%  span is missing  consider missing span as anomaly
        missing_span = np.random.rand() < 0.2
        span_id = f"{trace_id[idx]}_{service}"
        if missing_span:
            data.append([t, trace_id[idx], span_id, parent_id, service, duration[idx, s_idx], 1])
            continue
        data.append([t, trace_id[idx], span_id, parent_id, service, duration[idx, s_idx], 0])
        parent_id = span_id

trace_df = pd.DataFrame(data, columns=['start_time','trace_id','span_id','parent_id','service','duration_ms','is_anomaly'])
trace_df
# Out:
#                start_time  trace_id                 span_id  \
# 0     2025-09-26 00:00:00         1              1_frontend
# 1     2025-09-26 00:00:00         1          1_auth-service
# 2     2025-09-26 00:00:00         1      1_database-service
# 3     2025-09-26 00:00:00         1         1_cache-service
# 4     2025-09-26 00:01:00         2              2_frontend
# ...                   ...       ...                     ...
# 39995 2025-10-02 22:38:00      9999      9999_cache-service
# 39996 2025-10-02 22:39:00     10000          10000_frontend
# 39997 2025-10-02 22:39:00     10000      10000_auth-service
# 39998 2025-10-02 22:39:00     10000  10000_database-service
# 39999 2025-10-02 22:39:00     10000     10000_cache-service
#
#                     parent_id           service  duration_ms  is_anomaly
# 0                        None          frontend           29           0
# 1                  1_frontend      auth-service           48           1
# 2                  1_frontend  database-service           48           0
# 3          1_database-service     cache-service           47           0
# 4                        None          frontend           24           0
# ...                       ...               ...          ...         ...
# 39995           9999_frontend     cache-service           49           0
# 39996                    None          frontend           38           0
# 39997          10000_frontend      auth-service           31           0
# 39998      10000_auth-service  database-service           49           0
# 39999  10000_database-service     cache-service           28           0
#
# [40000 rows x 7 columns]

# %% [markdown]
# # Anamoly detection

# %% [markdown]
# ### Isolation

# %%
pip install scikit-learn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: scikit-learn in c:\programdata\anaconda3\lib\site-packages (1.6.1)
# Requirement already satisfied: numpy>=1.19.5 in c:\programdata\anaconda3\lib\site-packages (from scikit-learn) (2.1.3)
# Requirement already satisfied: scipy>=1.6.0 in c:\programdata\anaconda3\lib\site-packages (from scikit-learn) (1.15.3)
# Requirement already satisfied: joblib>=1.2.0 in c:\programdata\anaconda3\lib\site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\programdata\anaconda3\lib\site-packages (from scikit-learn) (3.5.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
metrics_df
# Out:
#                timestamp  cpu_usage  mem_base  response_time
# 0    2022-04-13 00:00:00         21      1489            105
# 1    2022-04-13 00:01:00         17      1692            108
# 2    2022-04-13 00:02:00         14      1735            103
# 3    2022-04-13 00:03:00         14      1268            106
# 4    2022-04-13 00:04:00         21      1507            100
# ...                  ...        ...       ...            ...
# 9995 2022-04-19 22:35:00         21      1371            106
# 9996 2022-04-19 22:36:00         20      1554            106
# 9997 2022-04-19 22:37:00         17      1483            101
# 9998 2022-04-19 22:38:00         17      1434            109
# 9999 2022-04-19 22:39:00         16      1425            102
#
# [10000 rows x 4 columns]

# %%
from sklearn.ensemble import  IsolationForest

# X = metric'response_time']]
iso_forest = IsolationForest(n_estimators=100, contamination=0.05, random_state=42)
a = metrics_df[['cpu_usage', 'mem_base', 'response_time']]
metrics_df['anamoly_iso'] = iso_forest.fit_predict(a)  # -1 = anomaly, 1 = normal
metrics_df['anamoly_iso'] = metrics_df['anamoly_iso'].map({1:0, -1:1})  # -1 = anomaly, 1 = normal

from sklearn.svm import OneClassSVM

oc_svm = OneClassSVM(nu=0.05, kernel='rbf', gamma='auto')
X = metrics_df[['cpu_usage', 'mem_base', 'response_time']]
metrics_df['anomaly_svm'] = oc_svm.fit_predict(X)
metrics_df['anomaly_svm'] = metrics_df['anomaly_svm'].map({1: 0, -1: 1})



from scipy.stats import zscore

metrics_df['cpu_z'] = zscore(metrics_df['cpu_usage'])
metrics_df['cpu_anomaly_stat'] = metrics_df['cpu_z'].abs() > 3
metrics_df['cpu_anomaly_stat'] = metrics_df['cpu_anomaly_stat'].map({1: 0, -1: 1})

# %%
metrics_df
# Out:
#                timestamp  cpu_usage  mem_base  response_time  \
# 0    2025-09-26 00:00:00         20      1375            106
# 1    2025-09-26 00:01:00         18      1293            103
# 2    2025-09-26 00:02:00         14      1690            104
# 3    2025-09-26 00:03:00         19      1685            109
# 4    2025-09-26 00:04:00         21      1535            108
# ...                  ...        ...       ...            ...
# 9995 2025-10-02 22:35:00         17      1422            106
# 9996 2025-10-02 22:36:00         77      1734            422
# 9997 2025-10-02 22:37:00         20      1502            105
# 9998 2025-10-02 22:38:00         15      1623            105
# 9999 2025-10-02 22:39:00         13      1754            107
#
#                service  is_anomaly  anamoly_iso  anomaly_svm     cpu_z  \
# 0        cache-service           0            0            0 -0.034101
# 1             frontend           0            0            0 -0.184855
# 2     database-service           0            0            0 -0.486363
# 3         auth-service           0            0            0 -0.109478
# 4        cache-service           0            0            0  0.041276
# ...                ...         ...          ...          ...       ...
# 9995          frontend           0            0            1 -0.260232
# 9996  database-service           1            1            1  4.262393
# 9997     cache-service           0            0            0 -0.034101
# 9998  database-service           0            0            0 -0.410986
# 9999  database-service           0            0            0 -0.561740
#
#       cpu_anomaly_stat
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN
# ...                ...
# 9995               NaN
# 9996               NaN
# 9997               NaN
# 9998               NaN
# 9999               NaN
#
# [10000 rows x 10 columns]

# %%
import torch
import torch.nn as nn
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
X_scaled = scaler.fit_transform(X)


def create_seq(data, seq_length=10):
    seq = []
    for i in range(len(data) - seq_length):
        seq.append(data[i : i+seq_length])
    return torch.tensor(seq, dtype=torch.float32)

X_seq = create_seq(X_scaled) # shape: (num_sequences, seq_length, features)
# print(X_seq.shape)

class LSTManEncoder(nn.Module):
    def __init__(self, input_feature, hidden_feature = 32):
        super().__init__()
        self.encoder = nn.LSTM(input_size=input_feature, hidden_size=hidden_feature, batch_first=True)
        self.decoder = nn.LSTM(input_size=hidden_feature, hidden_size=input_feature, batch_first=True)


    def forward(self, x):
        out, (h, c) = self.encoder(x)
        # print(h.shape)
        # print(x.shape)
        h = h.repeat(x.size(1), 1, 1).permute(1,0,2)
        output, _ = self.decoder(h)
        return output

model = LSTManEncoder(input_feature=X_seq.shape[2])
a = model(X_seq)
loss_fn = nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.01)

for epoch in range(10):
    optimizer.zero_grad()
    output = model(X_seq)
    # print(output.shape)
    # print(X_seq.shape)
    loss = loss_fn(output, X_seq)
    loss.backward()
    optimizer.step()

with torch.no_grad():
    pred = model(X_seq)
    mse = ((pred - X_seq)**2).mean(dim=(1,2)).numpy()

threshold = mse.mean() + 3*mse.std()
print(threshold)
lstm_anomalies = np.where(mse > threshold)[0]
print(f"LSTMAutoencoder anamoloy :{len(lstm_anomalies)}")
# Out:
# C:\Users\OM CHIDDARWAR\AppData\Local\Temp\ipykernel_21792\2214304298.py:13: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at C:\actions-runner\_work\pytorch\pytorch\pytorch\torch\csrc\utils\tensor_new.cpp:256.)
#   return torch.tensor(seq, dtype=torch.float32)
# 0.1405184
# LSTMAutoencoder anamoloy :113

# %%
lstm_anomalies
# Out:
# array([ 639,  640,  641,  642,  674,  764,  765,  858,  859,  865, 1178,
#        1179, 1180, 1181, 1182, 1183, 1184, 1185, 1253, 1254, 1255, 1256,
#        1257, 1258, 1260, 1261, 2107, 2108, 2109, 2110, 2111, 2112, 2113,
#        2114, 2466, 2627, 2656, 2657, 2948, 2949, 2950, 3001, 4222, 5131,
#        5132, 5133, 5164, 5165, 5166, 5522, 5523, 5561, 5597, 5598, 5599,
#        5600, 5601, 5602, 5942, 5943, 5944, 5945, 5948, 6018, 6019, 6020,
#        6021, 6022, 7869, 7870, 7871, 8249, 8250, 8251, 8252, 8255, 8653,
#        8654, 8655, 8735, 8736, 8737, 8738, 8739, 8740, 8742, 8842, 8843,
#        8844, 8845, 8846, 8847, 8951, 8952, 8953, 8954, 8955, 8956, 8958,
#        8959, 9030, 9301, 9302, 9303, 9304, 9305, 9375, 9853, 9854, 9855,
#        9856, 9857, 9858])

# %%
service
# Out:
# 'cache-service'

# %%
log_df['level_num'] = log_df['level'].map({'INFO':0, 'WARN':1, 'ERROR':2})

log_df['error_flag'] = log_df['message'].str.contains('error|fail|timeout', case=False).astype(int)

# %%
from sklearn.ensemble import  IsolationForest

# X = metric'response_time']]
iso_forest = IsolationForest(n_estimators=100, contamination=0.05, random_state=42)
a = log_df[['level_num', 'error_flag']]
log_df['anamoly_iso'] = iso_forest.fit_predict(a)  # -1 = anomaly, 1 = normal

from sklearn.svm import OneClassSVM

oc_svm = OneClassSVM(nu=0.05, kernel='rbf', gamma='auto')
X = log_df[['level_num', 'error_flag']]
log_df['anomaly_svm'] = oc_svm.fit_predict(X)


from scipy.stats import zscore

log_df['cpu_z'] = zscore(log_df['error_flag'])
log_df['cpu_anomaly_stat'] = log_df['cpu_z'].abs() > 3

# %%
log_df
# Out:
#                                                timestamp level  \
# 0      DatetimeIndex(['2022-04-13 00:00:00', '2022-04...  INFO
# 1                                    2022-04-13 00:00:00  INFO
# 2      DatetimeIndex(['2022-04-13 00:00:00', '2022-04...  INFO
# 3                                    2022-04-13 00:01:00  INFO
# 4      DatetimeIndex(['2022-04-13 00:00:00', '2022-04...  INFO
# ...                                                  ...   ...
# 19995                                2022-04-19 22:37:00  INFO
# 19996  DatetimeIndex(['2022-04-13 00:00:00', '2022-04...  INFO
# 19997                                2022-04-19 22:38:00  INFO
# 19998  DatetimeIndex(['2022-04-13 00:00:00', '2022-04...  INFO
# 19999                                2022-04-19 22:39:00  INFO
#
#                                   message  level_num  error_flag  anamoly_iso  \
# 0           frontend operation successful          0           0            1
# 1           frontend operation successful          0           0            1
# 2           frontend operation successful          0           0            1
# 3           frontend operation successful          0           0            1
# 4      cache-service operation successful          0           0            1
# ...                                   ...        ...         ...          ...
# 19995       frontend operation successful          0           0            1
# 19996   auth-service operation successful          0           0            1
# 19997   auth-service operation successful          0           0            1
# 19998   auth-service operation successful          0           0            1
# 19999   auth-service operation successful          0           0            1
#
#        anomaly_svm     cpu_z  cpu_anomaly_stat
# 0                1 -0.333889             False
# 1                1 -0.333889             False
# 2                1 -0.333889             False
# 3                1 -0.333889             False
# 4                1 -0.333889             False
# ...            ...       ...               ...
# 19995            1 -0.333889             False
# 19996            1 -0.333889             False
# 19997            1 -0.333889             False
# 19998            1 -0.333889             False
# 19999            1 -0.333889             False
#
# [20000 rows x 9 columns]

# %%
metric_anamoly = metrics_df[metrics_df['anamoly_iso'] == 1]

# %%
metric_metadata = []
for _, row in metric_anamoly.iterrows():
    metadata = {
        "timestamp": row['timestamp'],
        "service": row.get('service','unknown'),  
        "component": "metric",
        "feature": "cpu_usage/mem_usage/response_time",  
        "value": row['cpu_usage'],
        "anomaly_type": "spike"
    }
    metric_metadata.append(metadata)

# %%
metric_metadata
# Out:
# [{'timestamp': Timestamp('2025-09-26 00:10:00'),
#   'service': 'auth-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 69,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-09-26 00:38:00'),
#   'service': 'auth-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 84,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-09-26 00:41:00'),
#   'service': 'auth-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 73,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-09-26 00:58:00'),
#   'service': 'cache-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 85,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-09-26 01:16:00'),
#   'service': 'cache-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 72,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-09-26 01:45:00'),
#   'service': 'cache-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 82,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-09-26 01:58:00'),
#   'service': 'auth-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 74,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-09-26 02:12:00'),
#   'service': 'database-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 84,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-09-26 02:27:00'),
#   'service': 'frontend',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 73,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-09-26 02:29:00'),
#   'service': 'cache-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 67,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-09-26 03:00:00'),
#   'service': 'frontend',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 70,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-09-26 03:12:00'),
#   'service': 'database-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 77,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-09-26 03:34:00'),
#   'service': 'frontend',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 84,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-09-26 03:37:00'),
#   'service': 'cache-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 75,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-09-26 03:53:00'),
#   'service': 'cache-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 75,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-09-26 05:02:00'),
#   'service': 'cache-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 84,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-09-26 05:17:00'),
#   'service': 'cache-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 76,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-09-26 05:21:00'),
#   'service': 'database-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 88,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-09-26 05:34:00'),
#   'service': 'cache-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 65,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-09-26 06:13:00'),
#   'service': 'frontend',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 73,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-09-26 06:55:00'),
#   'service': 'cache-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 79,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-09-26 07:09:00'),
#   'service': 'auth-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 74,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-09-26 07:12:00'),
#   'service': 'auth-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 71,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-09-26 07:22:00'),
#   'service': 'auth-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 78,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-09-26 07:30:00'),
#   'service': 'cache-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 90,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-09-26 07:40:00'),
#   'service': 'cache-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 73,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-09-26 07:48:00'),
#   'service': 'database-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 80,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-09-26 07:58:00'),
#   'service': 'database-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 80,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-09-26 08:17:00'),
#   'service': 'cache-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 67,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-09-26 08:19:00'),
#   'service': 'frontend',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 70,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-09-26 08:28:00'),
#   'service': 'cache-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 77,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-09-26 09:08:00'),
#   'service': 'database-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 69,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-09-26 09:19:00'),
#   'service': 'frontend',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 78,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-09-26 09:22:00'),
#   'service': 'database-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 78,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-09-26 09:58:00'),
#   'service': 'cache-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 79,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-09-26 10:12:00'),
#   'service': 'cache-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 77,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-09-26 10:42:00'),
#   'service': 'auth-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 80,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-09-26 10:43:00'),
#   'service': 'cache-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 69,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-09-26 10:48:00'),
#   'service': 'database-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 78,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-09-26 11:17:00'),
#   'service': 'database-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 78,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-09-26 11:18:00'),
#   'service': 'frontend',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 85,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-09-26 11:30:00'),
#   'service': 'auth-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 66,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-09-26 11:41:00'),
#   'service': 'frontend',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 70,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-09-26 12:17:00'),
#   'service': 'auth-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 78,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-09-26 12:30:00'),
#   'service': 'auth-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 69,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-09-26 12:45:00'),
#   'service': 'cache-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 83,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-09-26 12:50:00'),
#   'service': 'cache-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 73,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-09-26 12:53:00'),
#   'service': 'frontend',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 74,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-09-26 13:16:00'),
#   'service': 'frontend',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 82,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-09-26 14:04:00'),
#   'service': 'cache-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 74,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-09-26 14:06:00'),
#   'service': 'auth-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 77,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-09-26 14:19:00'),
#   'service': 'frontend',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 71,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-09-26 14:25:00'),
#   'service': 'auth-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 83,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-09-26 14:27:00'),
#   'service': 'auth-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 84,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-09-26 14:34:00'),
#   'service': 'database-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 83,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-09-26 14:48:00'),
#   'service': 'database-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 72,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-09-26 14:53:00'),
#   'service': 'cache-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 76,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-09-26 15:51:00'),
#   'service': 'frontend',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 81,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-09-26 16:39:00'),
#   'service': 'auth-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 75,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-09-26 16:45:00'),
#   'service': 'cache-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 70,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-09-26 17:26:00'),
#   'service': 'cache-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 73,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-09-26 17:47:00'),
#   'service': 'database-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 68,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-09-26 17:58:00'),
#   'service': 'cache-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 70,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-09-26 17:59:00'),
#   'service': 'database-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 80,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-09-26 18:54:00'),
#   'service': 'database-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 65,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-09-26 18:57:00'),
#   'service': 'frontend',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 79,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-09-26 19:30:00'),
#   'service': 'database-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 70,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-09-26 19:35:00'),
#   'service': 'frontend',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 72,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-09-26 19:43:00'),
#   'service': 'database-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 72,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-09-26 19:45:00'),
#   'service': 'auth-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 70,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-09-26 19:47:00'),
#   'service': 'auth-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 89,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-09-26 19:53:00'),
#   'service': 'frontend',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 78,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-09-26 20:58:00'),
#   'service': 'auth-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 82,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-09-26 21:01:00'),
#   'service': 'auth-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 76,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-09-26 21:02:00'),
#   'service': 'auth-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 79,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-09-26 21:25:00'),
#   'service': 'database-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 74,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-09-26 21:45:00'),
#   'service': 'cache-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 84,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-09-26 22:25:00'),
#   'service': 'frontend',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 68,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-09-26 23:06:00'),
#   'service': 'frontend',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 73,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-09-26 23:20:00'),
#   'service': 'cache-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 75,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-09-27 00:04:00'),
#   'service': 'frontend',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 67,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-09-27 00:45:00'),
#   'service': 'frontend',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 75,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-09-27 01:05:00'),
#   'service': 'cache-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 79,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-09-27 02:03:00'),
#   'service': 'auth-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 91,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-09-27 02:45:00'),
#   'service': 'frontend',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 65,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-09-27 03:06:00'),
#   'service': 'database-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 77,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-09-27 03:20:00'),
#   'service': 'cache-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 76,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-09-27 03:30:00'),
#   'service': 'database-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 84,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-09-27 03:40:00'),
#   'service': 'auth-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 71,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-09-27 04:02:00'),
#   'service': 'cache-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 68,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-09-27 04:16:00'),
#   'service': 'cache-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 81,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-09-27 05:03:00'),
#   'service': 'frontend',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 74,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-09-27 05:29:00'),
#   'service': 'cache-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 78,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-09-27 06:03:00'),
#   'service': 'frontend',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 78,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-09-27 06:04:00'),
#   'service': 'cache-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 79,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-09-27 06:14:00'),
#   'service': 'cache-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 80,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-09-27 06:23:00'),
#   'service': 'database-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 72,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-09-27 06:38:00'),
#   'service': 'frontend',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 78,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-09-27 06:43:00'),
#   'service': 'database-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 80,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-09-27 07:10:00'),
#   'service': 'auth-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 76,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-09-27 07:15:00'),
#   'service': 'database-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 82,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-09-27 07:42:00'),
#   'service': 'database-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 72,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-09-27 08:16:00'),
#   'service': 'auth-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 77,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-09-27 09:15:00'),
#   'service': 'cache-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 76,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-09-27 09:34:00'),
#   'service': 'auth-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 65,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-09-27 09:45:00'),
#   'service': 'database-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 76,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-09-27 09:49:00'),
#   'service': 'frontend',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 72,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-09-27 10:10:00'),
#   'service': 'cache-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 80,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-09-27 10:31:00'),
#   'service': 'auth-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 76,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-09-27 10:50:00'),
#   'service': 'auth-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 76,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-09-27 11:08:00'),
#   'service': 'auth-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 74,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-09-27 11:14:00'),
#   'service': 'auth-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 68,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-09-27 11:16:00'),
#   'service': 'auth-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 90,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-09-27 11:17:00'),
#   'service': 'database-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 70,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-09-27 11:41:00'),
#   'service': 'database-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 73,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-09-27 12:07:00'),
#   'service': 'auth-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 68,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-09-27 12:23:00'),
#   'service': 'frontend',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 83,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-09-27 12:53:00'),
#   'service': 'cache-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 80,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-09-27 14:38:00'),
#   'service': 'auth-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 91,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-09-27 14:40:00'),
#   'service': 'frontend',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 74,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-09-27 15:10:00'),
#   'service': 'database-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 82,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-09-27 15:15:00'),
#   'service': 'cache-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 86,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-09-27 15:30:00'),
#   'service': 'auth-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 77,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-09-27 16:16:00'),
#   'service': 'auth-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 78,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-09-27 16:42:00'),
#   'service': 'database-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 70,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-09-27 17:06:00'),
#   'service': 'database-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 78,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-09-27 17:13:00'),
#   'service': 'cache-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 75,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-09-27 17:15:00'),
#   'service': 'frontend',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 70,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-09-27 17:48:00'),
#   'service': 'cache-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 80,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-09-27 18:03:00'),
#   'service': 'cache-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 67,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-09-27 18:04:00'),
#   'service': 'frontend',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 83,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-09-27 18:05:00'),
#   'service': 'frontend',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 70,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-09-27 18:58:00'),
#   'service': 'frontend',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 71,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-09-27 19:17:00'),
#   'service': 'database-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 80,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-09-27 19:47:00'),
#   'service': 'cache-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 85,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-09-27 19:50:00'),
#   'service': 'database-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 64,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-09-27 20:17:00'),
#   'service': 'auth-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 73,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-09-27 20:24:00'),
#   'service': 'frontend',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 76,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-09-27 20:25:00'),
#   'service': 'frontend',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 76,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-09-27 20:42:00'),
#   'service': 'frontend',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 74,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-09-27 22:05:00'),
#   'service': 'cache-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 78,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-09-27 22:33:00'),
#   'service': 'cache-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 84,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-09-27 22:52:00'),
#   'service': 'cache-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 74,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-09-27 23:06:00'),
#   'service': 'database-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 74,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-09-27 23:17:00'),
#   'service': 'cache-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 74,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-09-27 23:40:00'),
#   'service': 'database-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 75,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-09-28 00:16:00'),
#   'service': 'database-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 74,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-09-28 00:30:00'),
#   'service': 'database-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 67,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-09-28 00:37:00'),
#   'service': 'database-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 64,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-09-28 00:51:00'),
#   'service': 'auth-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 74,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-09-28 00:56:00'),
#   'service': 'frontend',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 88,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-09-28 01:10:00'),
#   'service': 'auth-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 75,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-09-28 01:12:00'),
#   'service': 'cache-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 82,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-09-28 01:17:00'),
#   'service': 'cache-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 80,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-09-28 02:07:00'),
#   'service': 'cache-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 66,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-09-28 02:10:00'),
#   'service': 'cache-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 72,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-09-28 02:41:00'),
#   'service': 'frontend',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 71,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-09-28 02:58:00'),
#   'service': 'frontend',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 89,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-09-28 03:02:00'),
#   'service': 'cache-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 78,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-09-28 03:37:00'),
#   'service': 'auth-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 88,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-09-28 06:04:00'),
#   'service': 'cache-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 78,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-09-28 06:19:00'),
#   'service': 'auth-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 80,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-09-28 06:28:00'),
#   'service': 'auth-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 74,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-09-28 06:46:00'),
#   'service': 'frontend',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 79,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-09-28 06:49:00'),
#   'service': 'cache-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 75,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-09-28 07:26:00'),
#   'service': 'frontend',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 70,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-09-28 07:56:00'),
#   'service': 'database-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 75,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-09-28 08:16:00'),
#   'service': 'cache-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 75,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-09-28 08:24:00'),
#   'service': 'database-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 71,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-09-28 08:34:00'),
#   'service': 'frontend',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 77,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-09-28 09:49:00'),
#   'service': 'cache-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 78,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-09-28 10:02:00'),
#   'service': 'cache-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 74,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-09-28 10:21:00'),
#   'service': 'auth-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 80,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-09-28 10:44:00'),
#   'service': 'cache-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 71,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-09-28 10:54:00'),
#   'service': 'auth-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 70,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-09-28 11:11:00'),
#   'service': 'database-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 81,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-09-28 11:41:00'),
#   'service': 'database-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 81,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-09-28 12:25:00'),
#   'service': 'frontend',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 78,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-09-28 12:34:00'),
#   'service': 'cache-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 82,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-09-28 13:13:00'),
#   'service': 'frontend',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 70,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-09-28 14:18:00'),
#   'service': 'database-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 72,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-09-28 14:28:00'),
#   'service': 'frontend',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 72,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-09-28 14:38:00'),
#   'service': 'database-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 72,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-09-28 14:47:00'),
#   'service': 'cache-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 85,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-09-28 15:17:00'),
#   'service': 'cache-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 71,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-09-28 15:30:00'),
#   'service': 'cache-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 77,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-09-28 15:34:00'),
#   'service': 'auth-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 78,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-09-28 15:40:00'),
#   'service': 'cache-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 81,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-09-28 16:17:00'),
#   'service': 'cache-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 84,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-09-28 16:20:00'),
#   'service': 'cache-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 84,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-09-28 17:09:00'),
#   'service': 'database-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 83,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-09-28 17:11:00'),
#   'service': 'cache-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 91,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-09-28 17:37:00'),
#   'service': 'cache-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 64,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-09-28 17:50:00'),
#   'service': 'cache-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 82,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-09-28 19:00:00'),
#   'service': 'frontend',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 85,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-09-28 19:30:00'),
#   'service': 'auth-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 75,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-09-28 19:59:00'),
#   'service': 'auth-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 69,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-09-28 20:14:00'),
#   'service': 'auth-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 77,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-09-28 20:41:00'),
#   'service': 'auth-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 73,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-09-28 20:46:00'),
#   'service': 'auth-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 83,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-09-28 20:58:00'),
#   'service': 'database-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 87,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-09-28 21:23:00'),
#   'service': 'frontend',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 70,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-09-28 21:37:00'),
#   'service': 'auth-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 82,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-09-28 21:45:00'),
#   'service': 'frontend',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 81,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-09-28 22:05:00'),
#   'service': 'database-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 83,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-09-28 22:22:00'),
#   'service': 'database-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 76,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-09-28 22:30:00'),
#   'service': 'auth-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 87,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-09-28 22:31:00'),
#   'service': 'database-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 74,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-09-28 22:49:00'),
#   'service': 'frontend',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 71,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-09-28 22:58:00'),
#   'service': 'auth-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 78,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-09-28 23:01:00'),
#   'service': 'cache-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 80,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-09-28 23:16:00'),
#   'service': 'auth-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 79,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-09-28 23:49:00'),
#   'service': 'auth-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 87,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-09-29 00:22:00'),
#   'service': 'cache-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 78,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-09-29 00:25:00'),
#   'service': 'cache-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 75,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-09-29 00:34:00'),
#   'service': 'database-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 72,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-09-29 00:39:00'),
#   'service': 'database-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 71,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-09-29 00:57:00'),
#   'service': 'frontend',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 78,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-09-29 01:59:00'),
#   'service': 'frontend',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 83,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-09-29 02:03:00'),
#   'service': 'auth-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 72,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-09-29 02:20:00'),
#   'service': 'cache-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 69,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-09-29 02:30:00'),
#   'service': 'auth-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 65,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-09-29 02:37:00'),
#   'service': 'database-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 76,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-09-29 02:45:00'),
#   'service': 'frontend',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 79,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-09-29 03:03:00'),
#   'service': 'database-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 78,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-09-29 04:12:00'),
#   'service': 'frontend',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 76,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-09-29 04:19:00'),
#   'service': 'cache-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 70,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-09-29 04:26:00'),
#   'service': 'frontend',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 77,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-09-29 04:39:00'),
#   'service': 'cache-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 74,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-09-29 05:13:00'),
#   'service': 'cache-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 75,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-09-29 05:45:00'),
#   'service': 'database-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 76,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-09-29 06:11:00'),
#   'service': 'cache-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 64,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-09-29 06:45:00'),
#   'service': 'database-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 64,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-09-29 07:32:00'),
#   'service': 'frontend',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 66,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-09-29 08:40:00'),
#   'service': 'cache-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 85,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-09-29 09:04:00'),
#   'service': 'auth-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 73,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-09-29 10:04:00'),
#   'service': 'cache-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 87,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-09-29 10:52:00'),
#   'service': 'auth-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 71,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-09-29 10:58:00'),
#   'service': 'auth-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 76,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-09-29 11:28:00'),
#   'service': 'frontend',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 80,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-09-29 11:46:00'),
#   'service': 'cache-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 71,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-09-29 11:53:00'),
#   'service': 'auth-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 79,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-09-29 12:04:00'),
#   'service': 'frontend',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 77,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-09-29 12:50:00'),
#   'service': 'frontend',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 82,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-09-29 13:33:00'),
#   'service': 'cache-service',
#   'component': 'metric',
# ...
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 76,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-10-01 23:02:00'),
#   'service': 'frontend',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 82,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-10-01 23:10:00'),
#   'service': 'database-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 73,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-10-01 23:16:00'),
#   'service': 'cache-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 77,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-10-01 23:38:00'),
#   'service': 'cache-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 68,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-10-02 00:00:00'),
#   'service': 'cache-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 82,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-10-02 00:15:00'),
#   'service': 'database-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 85,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-10-02 00:19:00'),
#   'service': 'database-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 73,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-10-02 00:22:00'),
#   'service': 'database-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 87,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-10-02 00:34:00'),
#   'service': 'auth-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 72,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-10-02 01:39:00'),
#   'service': 'frontend',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 82,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-10-02 01:40:00'),
#   'service': 'database-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 81,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-10-02 01:44:00'),
#   'service': 'database-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 74,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-10-02 01:46:00'),
#   'service': 'cache-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 75,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-10-02 02:07:00'),
#   'service': 'database-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 78,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-10-02 02:14:00'),
#   'service': 'cache-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 77,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-10-02 03:27:00'),
#   'service': 'cache-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 73,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-10-02 03:29:00'),
#   'service': 'auth-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 76,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-10-02 03:31:00'),
#   'service': 'frontend',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 86,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-10-02 03:48:00'),
#   'service': 'cache-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 80,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-10-02 03:53:00'),
#   'service': 'frontend',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 91,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-10-02 04:16:00'),
#   'service': 'database-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 69,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-10-02 04:27:00'),
#   'service': 'database-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 67,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-10-02 04:54:00'),
#   'service': 'database-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 73,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-10-02 04:55:00'),
#   'service': 'frontend',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 74,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-10-02 05:09:00'),
#   'service': 'cache-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 76,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-10-02 05:15:00'),
#   'service': 'cache-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 69,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-10-02 05:19:00'),
#   'service': 'frontend',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 87,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-10-02 05:20:00'),
#   'service': 'cache-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 76,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-10-02 05:49:00'),
#   'service': 'frontend',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 81,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-10-02 05:51:00'),
#   'service': 'cache-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 78,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-10-02 06:12:00'),
#   'service': 'auth-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 79,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-10-02 06:30:00'),
#   'service': 'cache-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 81,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-10-02 06:39:00'),
#   'service': 'frontend',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 89,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-10-02 07:29:00'),
#   'service': 'database-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 75,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-10-02 07:47:00'),
#   'service': 'frontend',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 80,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-10-02 10:39:00'),
#   'service': 'auth-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 76,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-10-02 10:47:00'),
#   'service': 'frontend',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 64,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-10-02 11:05:00'),
#   'service': 'cache-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 72,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-10-02 11:07:00'),
#   'service': 'frontend',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 75,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-10-02 11:09:00'),
#   'service': 'auth-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 80,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-10-02 11:27:00'),
#   'service': 'frontend',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 69,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-10-02 11:49:00'),
#   'service': 'frontend',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 75,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-10-02 11:50:00'),
#   'service': 'auth-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 68,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-10-02 12:12:00'),
#   'service': 'cache-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 88,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-10-02 12:15:00'),
#   'service': 'auth-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 72,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-10-02 12:16:00'),
#   'service': 'cache-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 70,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-10-02 12:23:00'),
#   'service': 'frontend',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 86,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-10-02 13:17:00'),
#   'service': 'database-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 71,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-10-02 13:24:00'),
#   'service': 'database-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 70,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-10-02 14:25:00'),
#   'service': 'auth-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 67,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-10-02 14:58:00'),
#   'service': 'cache-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 89,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-10-02 14:59:00'),
#   'service': 'cache-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 82,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-10-02 15:32:00'),
#   'service': 'auth-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 73,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-10-02 15:50:00'),
#   'service': 'auth-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 69,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-10-02 16:06:00'),
#   'service': 'cache-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 86,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-10-02 16:20:00'),
#   'service': 'auth-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 78,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-10-02 16:21:00'),
#   'service': 'auth-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 77,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-10-02 16:41:00'),
#   'service': 'database-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 79,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-10-02 16:52:00'),
#   'service': 'cache-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 81,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-10-02 17:05:00'),
#   'service': 'frontend',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 69,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-10-02 17:11:00'),
#   'service': 'frontend',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 83,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-10-02 17:35:00'),
#   'service': 'database-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 73,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-10-02 17:57:00'),
#   'service': 'database-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 83,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-10-02 18:46:00'),
#   'service': 'auth-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 75,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-10-02 19:09:00'),
#   'service': 'cache-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 65,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-10-02 19:14:00'),
#   'service': 'frontend',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 80,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-10-02 19:23:00'),
#   'service': 'frontend',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 76,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-10-02 19:28:00'),
#   'service': 'auth-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 75,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-10-02 19:36:00'),
#   'service': 'auth-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 84,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-10-02 19:53:00'),
#   'service': 'cache-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 82,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-10-02 20:17:00'),
#   'service': 'auth-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 71,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-10-02 20:18:00'),
#   'service': 'frontend',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 65,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-10-02 20:22:00'),
#   'service': 'cache-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 77,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-10-02 20:26:00'),
#   'service': 'database-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 83,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-10-02 20:30:00'),
#   'service': 'auth-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 86,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-10-02 20:47:00'),
#   'service': 'cache-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 69,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-10-02 21:00:00'),
#   'service': 'cache-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 69,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-10-02 21:06:00'),
#   'service': 'frontend',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 82,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-10-02 21:31:00'),
#   'service': 'cache-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 84,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-10-02 22:34:00'),
#   'service': 'cache-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 86,
#   'anomaly_type': 'spike'},
#  {'timestamp': Timestamp('2025-10-02 22:36:00'),
#   'service': 'database-service',
#   'component': 'metric',
#   'feature': 'cpu_usage/mem_usage/response_time',
#   'value': 77,
#   'anomaly_type': 'spike'}]

# %%
import getpass
import os

if "GOOGLE_API_KEY" not in os.environ:
    os.environ["GOOGLE_API_KEY"] = "AIzaSyCpCk8y8l3IU08n9_u_EWajQv-pibrBdps"

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_core.prompts import PromptTemplate

def get_cause_llm(metric_metadata):

    client = ChatGoogleGenerativeAI(model="gemini-2.5-flash")

    prompt = """
    You are an expert in system monitoring and root cause analysis.
    Given the anomaly metadata below, suggest possible root causes.
    Metadata: {metadata}
        Return the response as structured JSON with fields:
    - root_cause
    - severity
    - suggested_action

    Answer in simple and short
    """

    template = PromptTemplate(template=prompt, input_variables=['metadata'])
    formatted_prompt = template.format(metadata=metric_metadata)

    result = client.invoke(formatted_prompt).content

    return result

# %%
import json
def get_cause_llm(metric_metadata):
    client = ChatGoogleGenerativeAI(model="gemini-2.5-flash")

    prompt = """
        You are an expert in system monitoring and root cause analysis.
        Given the anomaly metadata below, suggest possible root causes.
        Metadata: {metadata}
        Return the response strictly in JSON format with fields:
        - root_cause
        - severity
        - suggested_action
        Also answer in short and simple in less words
    """

    template = PromptTemplate(template=prompt, input_variables=['metadata'])
    formatted_prompt = template.format(metadata=metric_metadata)

    print("\nExplaining the reason behind problem..............")
    raw_response = client.invoke(formatted_prompt).content

    try:
        cleaned = raw_response.strip().replace("```json", "").replace("```", "")
        parsed = json.loads(cleaned)  
        # print(json.dumps(parsed, indent=2))  
        return parsed
    except json.JSONDecodeError:
        print("Model didn't return proper JSON, raw response shown:")
        # print(raw_response)
        return {"raw_response": raw_response}

# %%
get_cause_llm(metric_metadata)
# Out:
# Explaining the reason behind problem..............
# {'root_cause': 'Widespread resource contention and performance bottlenecks across core services (auth, cache, database, frontend), likely triggered by increased workload, inefficient code/queries, or underlying infrastructure limitations.',
#  'severity': 'High',
#  'suggested_action': 'Immediately review traffic patterns and recent deployments. Deep-dive into database and cache performance metrics, and consider scaling resources or optimizing application code.'}

# %%
print("Generating event data (vectorized)...")
service_col = services[np.random.randint(0, len(services), size=n)]
event_col = event_types[np.random.randint(0, len(event_types), size=n)]

df = pd.DataFrame({
    'timestamp': timestamp,
    'event_type': event_col,
    'service': service_col
})
# Out:
# Generating event data (vectorized)...
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 print("Generating event data (vectorized)...")
# ----> 2 service_col = services[np.random.randint(0, len(services), size=n)]
#       3 event_col = event_types[np.random.randint(0, len(event_types), size=n)]
#       5 df = pd.DataFrame({
#       6     'timestamp': timestamp,
#       7     'event_type': event_col,
#       8     'service': service_col
#       9 })
#
# NameError: name 'services' is not defined
